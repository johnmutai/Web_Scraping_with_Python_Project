# %% [markdown]
# # <font color='#2F4F4F'>Web Scraping with Python Project

# %% [markdown]
# ## <font color='#2F4F4F'>Prerequisites</font>

# %%
# We first import the required libraries
# ---
#
import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1: Obtaining our Data</font>

# %%
# PigiaMe: https://www.pigiame.co.ke/it-software-jobs
# ---
#
pigia_me = requests.get('https://www.pigiame.co.ke/it-software-jobs')
pigia_me
# Out:
# <Response [200]>

# %%
# MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
# ---
#
my_job_mag = requests.get('https://www.myjobmag.co.ke/jobs-by-field/information-technology')
my_job_mag
# Out:
# <Response [200]>

# %%
# KenyanJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133
# ---
#
kenyan_job = requests.get('https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133')
kenyan_job
# Out:
# <Response [200]>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2: Parsing</font>

# %%
# Parsing our document: pigia_me
# ---
# 
soup_pm = BeautifulSoup(pigia_me.content, "html.parser")

# %%
# Parsing our document: my_job_mag
# ---
#  
soup_mjm = BeautifulSoup(my_job_mag.text, "html.parser")

# %%
# Parsing our document: kenyan_job
# ---
# 
soup_kj = BeautifulSoup(kenyan_job.text, "html.parser")

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3: Extracting Required Elements</font>

# %%
# 1. Extracting job titles and links: pigia me
# ---
# 
jobs = soup_pm.find_all("div", "listings-cards__list-item")

titles = []
links = []

for job in jobs:
  title = job.find('div', 'listing-card__header__title').get_text().strip()
  link =  job.a.get('href')
  titles.append(title)
  links.append(link)

# Create a Pandas dataframe from the lists
# df = pd.DataFrame({'Title': titles, 'Link': links})
# df

# %%
# 2. Extracting job titles: my_job_mag
# ---
# 

jobs_mgm = soup_mjm.find_all("li", "job-info")

titles_mjm = []
links_mjm = []

for job in jobs_mgm:
  title = job.h2.a.get_text().strip()
  link = 'https://www.myjobmag.co.ke/jobs-by-field/information-technology' + job.h2.a.get('href')
  titles_mjm.append(title)
  links_mjm.append(link)

# Create a Pandas dataframe from the lists
# df_mjm = pd.DataFrame({'Title': titles_mjm, 'Link': links_mjm})
# df_mjm

# %%
# 3. Extracting job titles: kenya_job
# ---

jobs_kj = soup_kj.find_all('div', 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title')

titles_kj = []
links_kj = []

for job in jobs_kj:
  title = job.h5.a.get_text().strip()
  link = 'https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133' + job.h5.a.get('href')
  titles_kj.append(title)
  links_kj.append(link)

# Create a Pandas dataframe from the lists
# df_kj = pd.DataFrame({'Title': titles_kj, 'Link': links_kj})
# df_kj

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4: Saving our Data</font>

# %%
# Saving the scraped contents in a dataframe and preview our data
# ---
#

df_All = pd.DataFrame({'Title': (titles_kj + titles_mjm + titles), 'Link': (links_kj + links_mjm + links)})
df_All
# Out:
#                                                 Title  \
# 0          JAVA EE / JAVA 8 Developer with SQL Skills
# 1                       Senior Freelance Web Designer
# 2             CCTV and Fire Alarms Systems Technician
# 3             Information Technology Sales Specialist
# 4                           AWS Cloud Architect (M/F)
# 5                       AWS Solutions Architect (M/F)
# 6                     AZURE Solutions Architect (M/F)
# 7                               Cloud Architect (M/F)
# 8   Cloud Computing and Virtualization Engineer (M/F)
# 9                                Cloud Engineer (M/F)
# 10                Cloud Microservices Architect (M/F)
# 11                   Cloud System Administrator (M/F)
# 12                      Cloud System Integrator (M/F)
# 13                      Cyber Security Engineer (M/F)
# 14                          DATASTAGE Architect (M/F)
# 15                            GENESYS Architect (M/F)
# 16                            Network Architect (M/F)
# 17                            ANGULAR Developer (M/F)
# 18                              DevOps Engineer (M/F)
# 19                             DOTNET Developer (M/F)
# 20                                IOS Developer (M/F)
# 21                               JAVA Developer (M/F)
# 22                           JAVA JEE Developer (M/F)
# 23                         JAVASCRIPT Developer (M/F)
# 24                             KOTLIN Developer (M/F)
# 25  Lecturer in Computer Science at University of ...
# 26  Senior Lecturer- Computer Science at Universit...
# 27  Associate Professor- Computer Science at Unive...
# 28  Professor- Computer Science at University of Embu
# 29  Open MRS/React JS Developer at University of N...
# 30  Information Communication Technology Officer I...
# 31            Head, Technology at Standard Bank Group
# 32  Senior Graphic Designer at Hotpoint Appliances...
# 33  Senior Manager: Technology Programme Managemen...
# 34          Network Engineer at Madison Group Limited
# 35                    Product Engineer at Access Afya
# 36              Data Platform Engineer at Access Afya
# 37               Security Product Architect at Azenia
# 38            Mid Machine Learning Engineer at Azenia
# 39               Technical Business Analyst at Azenia
# 40        Supply Technical Business Analyst at Azenia
# 41  Climate Forecaster (Machine Learning Expert) a...
# 42            Networks Administrator at One Acre Fund
# 43                    Python and JavaScript Developer
# 44                                 Software Developer
# 45  Software Development Java, nodeJs (Onsite Nyer...
# 46                         Frontend Developer Reframe
# 47                                  Chatbot Developer
# 48                         Assistant IT Administrator
# 49                                        CRM Enginee
# 50                                 Analyst Programmer
# 51                              Senior Game Developer
# 52                           Lead Full Stack Engineer
#
#                                                  Link
# 0   https://www.kenyajob.com/job-vacancies-search-...
# 1   https://www.kenyajob.com/job-vacancies-search-...
# 2   https://www.kenyajob.com/job-vacancies-search-...
# 3   https://www.kenyajob.com/job-vacancies-search-...
# 4   https://www.kenyajob.com/job-vacancies-search-...
# 5   https://www.kenyajob.com/job-vacancies-search-...
# 6   https://www.kenyajob.com/job-vacancies-search-...
# 7   https://www.kenyajob.com/job-vacancies-search-...
# 8   https://www.kenyajob.com/job-vacancies-search-...
# 9   https://www.kenyajob.com/job-vacancies-search-...
# 10  https://www.kenyajob.com/job-vacancies-search-...
# 11  https://www.kenyajob.com/job-vacancies-search-...
# 12  https://www.kenyajob.com/job-vacancies-search-...
# 13  https://www.kenyajob.com/job-vacancies-search-...
# 14  https://www.kenyajob.com/job-vacancies-search-...
# 15  https://www.kenyajob.com/job-vacancies-search-...
# 16  https://www.kenyajob.com/job-vacancies-search-...
# 17  https://www.kenyajob.com/job-vacancies-search-...
# 18  https://www.kenyajob.com/job-vacancies-search-...
# 19  https://www.kenyajob.com/job-vacancies-search-...
# 20  https://www.kenyajob.com/job-vacancies-search-...
# 21  https://www.kenyajob.com/job-vacancies-search-...
# 22  https://www.kenyajob.com/job-vacancies-search-...
# 23  https://www.kenyajob.com/job-vacancies-search-...
# 24  https://www.kenyajob.com/job-vacancies-search-...
# 25  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 26  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 27  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 28  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 29  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 30  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 31  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 32  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 33  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 34  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 35  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 36  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 37  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 38  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 39  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 40  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 41  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 42  https://www.myjobmag.co.ke/jobs-by-field/infor...
# 43  https://www.pigiame.co.ke/listings/python-and-...
# 44  https://www.pigiame.co.ke/listings/software-de...
# 45  https://www.pigiame.co.ke/listings/software-de...
# 46  https://www.pigiame.co.ke/listings/frontend-de...
# 47  https://www.pigiame.co.ke/listings/chatbot-dev...
# 48  https://www.pigiame.co.ke/listings/assistant-i...
# 49  https://www.pigiame.co.ke/listings/crm-enginee...
# 50  https://www.pigiame.co.ke/listings/analyst-pro...
# 51  https://www.pigiame.co.ke/listings/senior-game...
# 52  https://www.pigiame.co.ke/listings/lead-full-s...
